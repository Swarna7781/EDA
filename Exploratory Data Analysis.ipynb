# %%
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('food_coded.csv')

# %%
df.head()
# Out:
#      GPA  Gender  breakfast  calories_chicken  calories_day  calories_scone  \
# 0    2.4       2          1               430           NaN           315.0
# 1  3.654       1          1               610           3.0           420.0
# 2    3.3       1          1               720           4.0           420.0
# 3    3.2       1          1               430           3.0           420.0
# 4    3.5       1          1               720           2.0           420.0
#
#    coffee                      comfort_food        comfort_food_reasons  \
# 0       1                              none       we dont have comfort
# 1       2       chocolate, chips, ice cream        Stress, bored, anger
# 2       2   frozen yogurt, pizza, fast food             stress, sadness
# 3       2  Pizza, Mac and cheese, ice cream                     Boredom
# 4       2      Ice cream, chocolate, chips   Stress, boredom, cravings
#
# ...

# %%
to_drop= ['GPA','Gender','breakfast', 'calories_chicken', 'calories_day', 'calories_scone', 'coffee', 'comfort_food',
          'comfort_food_reasons','comfort_food_reasons_coded','soup','comfort_food_reasons_coded.1','cuisine','diet_current',
           'diet_current_coded','drink','eating_changes','eating_changes_coded','eating_changes_coded1','self_perception_weight',
          'thai_food', 'tortilla_calories', 'turkey_calories', 'type_sports', 'vitamins', 'waffle_calories','weight','father_education',
            'father_profession', 'fav_cuisine', 'fav_cuisine_coded', 'fav_food', 'meals_dinner_friend', 'mother_education', 'mother_profession',
            'nutritional_check', 'parents_cook','persian_food', 'food_childhood' , 'fries','grade_level', 'greek_food', 'ideal_diet_coded',
         'indian_food', 'italian_food', 'life_rewarding', 'marital_status','healthy_feeling', 'healthy_meal', 'ideal_diet' ]

# %%
df.drop(to_drop, inplace= True, axis= 1 )

# %%
df.head()
# Out:
#    cook  eating_out  employment  ethnic_food  exercise  fruit_day  income  \
# 0   2.0           3         3.0            1       1.0          5     5.0
# 1   3.0           2         2.0            4       1.0          4     4.0
# 2   1.0           2         3.0            5       2.0          5     6.0
# 3   2.0           2         3.0            5       3.0          4     6.0
# 4   1.0           2         2.0            4       1.0          4     6.0
#
#    on_off_campus  pay_meal_out  sports  veggies_day
# 0            1.0             2     1.0            5
# 1            1.0             4     1.0            4
# 2            2.0             3     2.0            5
# 3            1.0             2     2.0            3
# 4            1.0             4     1.0            4

# %%
sns.boxplot(data= df , width=0.5)
# Out:
# <Axes: >

# %%
df.shape
# Out:
# (116, 11)

# %%
df.tail(40)
# Out:
#      cook  eating_out  employment  ethnic_food  exercise  fruit_day  income  \
# 81    3.0           3         3.0            4       1.0          4     4.0
# 82    NaN           5         3.0            4       1.0          3     3.0
# 84    1.0           2         3.0            5       1.0          5     5.0
# 85    3.0           3         2.0            3       3.0          5     6.0
# 86    2.0           1         3.0            4       2.0          5     6.0
# 87    4.0           2         2.0            3       1.0          4     6.0
# 88    NaN           1         2.0            5       1.0          4     2.0
# 89    3.0           2         2.0            5       1.0          5     3.0
# 90    4.0           2         3.0            3       1.0          5     6.0
# 91    2.0           3         2.0            2       2.0          2     6.0
# 92    2.0           5         2.0            1       3.0          1     3.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 116 entries, 0 to 124
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   cook           113 non-null    float64
#  1   eating_out     116 non-null    int64
#  2   employment     116 non-null    float64
#  3   ethnic_food    116 non-null    int64
#  4   exercise       106 non-null    float64
#  5   fruit_day      116 non-null    int64
#  6   income         115 non-null    float64
#  7   on_off_campus  116 non-null    float64
#  8   pay_meal_out   116 non-null    int64
#  9   sports         114 non-null    float64
#  10  veggies_day    116 non-null    int64
# dtypes: float64(6), int64(5)
# memory usage: 10.9 KB

# %%
df.dropna(subset=['employment'], inplace=True)

# %%
plt.scatter(df['employment'],df['income'])

# %%
X = df.iloc[: , [1,7]].values

# %%
X.shape
# Out:
# (116, 2)

# %%
#WCSS = Within cluster sum of square
from sklearn.cluster import KMeans
wcss = []

# %%
for i in range (1,11):
 kmeans = KMeans(n_clusters=i , init='k-means++', random_state=0)
 kmeans.fit(X)
 wcss.append(kmeans.inertia_)

# %%
 #Our optimal K value is where the elbow shape occurs, we can see from k=5, the graph decreases drastically
plt.plot(range(1,11), wcss)
plt.title('Elbow method')
plt.xlabel('no. of clusters')
plt.ylabel('WCSS values')
# Out:
# Text(0, 0.5, 'WCSS values')

# %%
sns.boxplot(data= X, width=0.5)
# Out:
# <Axes: >

# %%
correlation= df.corr()

# %%
sns.heatmap(correlation, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
# Out:
# <Axes: >

# %%
sns.pairplot(df)
